# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os

# %%
visuals_path = "visuals"
if not os.path.exists(visuals_path):
    os.makedirs(visuals_path)

# %%
df = pd.read_csv("StressLevelDataset.csv")

# %%
df.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 1100 non-null   int64
#  1   self_esteem                   1100 non-null   int64
#  2   mental_health_history         1100 non-null   int64
#  3   depression                    1100 non-null   int64
#  4   headache                      1100 non-null   int64
#  5   blood_pressure                1100 non-null   int64
#  6   sleep_quality                 1100 non-null   int64
#  7   breathing_problem             1100 non-null   int64
#  8   noise_level                   1100 non-null   int64
#  9   living_conditions             1100 non-null   int64
#  10  safety                        1100 non-null   int64
#  11  basic_needs                   1100 non-null   int64
#  12  academic_performance          1100 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# anxiety_level                   0
# self_esteem                     0
# mental_health_history           0
# depression                      0
# headache                        0
# blood_pressure                  0
# sleep_quality                   0
# breathing_problem               0
# noise_level                     0
# living_conditions               0
# safety                          0
# basic_needs                     0
# academic_performance            0
# study_load                      0
# teacher_student_relationship    0
# future_career_concerns          0
# social_support                  0
# peer_pressure                   0
# extracurricular_activities      0
# bullying                        0
# stress_level                    0
# dtype: int64

# %%
df.describe()
# Out:
#        anxiety_level  self_esteem  mental_health_history   depression  \
# count    1100.000000  1100.000000            1100.000000  1100.000000
# mean       11.063636    17.777273               0.492727    12.555455
# std         6.117558     8.944599               0.500175     7.727008
# min         0.000000     0.000000               0.000000     0.000000
# 25%         6.000000    11.000000               0.000000     6.000000
# 50%        11.000000    19.000000               0.000000    12.000000
# 75%        16.000000    26.000000               1.000000    19.000000
# max        21.000000    30.000000               1.000000    27.000000
#
#           headache  blood_pressure  sleep_quality  breathing_problem  \
# count  1100.000000     1100.000000    1100.000000        1100.000000
# mean      2.508182        2.181818       2.660000           2.753636
# std       1.409356        0.833575       1.548383           1.400713
# ...

# %%
#The relationship between study load and stress level
sns.boxplot(x="stress_level", y="study_load", data=df)
plt.title("study load vs stress level")
plt.ylabel("Study load ")
plt.xlabel("Stress level")
plt.savefig("visuals/study_load_vs_stress.png")

plt.show()

# %%
#estimating stress level

# %%
X = df.drop("stress_level",axis=1)
y=df["stress_level"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test,y_train,y_test= train_test_split(X,y, test_size = 0.25, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# %%
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)

print(" Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_lr))
print(classification_report(y_test, y_pred_lr))
# Out:
#  Logistic Regression Accuracy: 0.8945454545454545
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.89        95
#            1       0.88      0.89      0.89        92
#            2       0.90      0.92      0.91        88
#
#     accuracy                           0.89       275
#    macro avg       0.89      0.90      0.89       275
# weighted avg       0.89      0.89      0.89       275

# %%
coefficients = pd.Series(lr.coef_[0], index=X.columns)
coefficients.sort_values().plot(kind='barh', figsize=(10,6))
plt.title("Logistic Regression Coefficients (Feature Importance)")
plt.show()

# %%
from sklearn.svm import SVC

# %%
svm = SVC(kernel='linear')
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test)

# %%
print("SVM Accuracy:", accuracy_score(y_test, y_pred_svm))
print(classification_report(y_test, y_pred_svm))
# Out:
# SVM Accuracy: 0.8981818181818182
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88        95
#            1       0.90      0.91      0.91        92
#            2       0.91      0.91      0.91        88
#
#     accuracy                           0.90       275
#    macro avg       0.90      0.90      0.90       275
# weighted avg       0.90      0.90      0.90       275

# %%
svm_coefficients = pd.Series(svm.coef_[0], index=X.columns)
svm_coefficients.sort_values().plot(kind='barh', figsize=(10,6))
plt.title("SVM Coefficients (Feature Importance)")
plt.show()

# %%
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)
lr_acc = accuracy_score(y_test, y_pred_lr)

# %%
svm = SVC(kernel='linear')
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test)
svm_acc = accuracy_score(y_test, y_pred_svm)

# %%
comparison = pd.DataFrame({
    "Model": ["Logistic Regression", "SVM (Linear)"],
    "Accuracy": [lr_acc, svm_acc]
})
print("Comparison of Models:\n", comparison)
# Out:
# Comparison of Models:
#                   Model  Accuracy
# 0  Logistic Regression  0.894545
# 1         SVM (Linear)  0.898182

# %%
coefficients = pd.Series(lr.coef_[0], index=X.columns)
coefficients.sort_values().plot(kind='barh', figsize=(10,8))
plt.title("Feature Coefficients (with Logistic Regression)")
plt.show()
